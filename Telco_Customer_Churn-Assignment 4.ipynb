# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-43-ca75ca9d6ff6> in <module>
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
# ----> 4 import seaborn as sns
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
#reading the Telco_Customer_Churn csv file
df=pd.read_csv("Telco_Customer_Churn.csv")
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
# 4          No          No              No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges  TotalCharges Churn
# 0           Electronic check          29.85         29.85    No
# 1               Mailed check          56.95        1889.5    No
# 2               Mailed check          53.85        108.15   Yes
# 3  Bank transfer (automatic)          42.30       1840.75    No
# 4           Electronic check          70.70        151.65   Yes
#
# [5 rows x 21 columns]

# %%
#Counting the top 10 most popular 
df['Count'] = 1
df.head(10)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
# 5  9305-CDSKC  Female              0      No         No       8          Yes
# 6  1452-KIOVK    Male              0      No        Yes      22          Yes
# 7  6713-OKOMC  Female              0      No         No      10           No
# 8  7892-POOKP  Female              0     Yes         No      28          Yes
# 9  6388-TABGU    Male              0      No        Yes      62          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... TechSupport  \
# 0  No phone service             DSL             No  ...          No
# 1                No             DSL            Yes  ...          No
# 2                No             DSL            Yes  ...          No
# 3  No phone service             DSL            Yes  ...         Yes
# 4                No     Fiber optic             No  ...          No
# 5               Yes     Fiber optic             No  ...          No
# 6               Yes     Fiber optic             No  ...          No
# 7  No phone service             DSL            Yes  ...          No
# 8               Yes     Fiber optic             No  ...         Yes
# 9                No             DSL            Yes  ...          No
#
#   StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No              No  Month-to-month              Yes
# 1          No              No        One year               No
# 2          No              No  Month-to-month              Yes
# 3          No              No        One year               No
# 4          No              No  Month-to-month              Yes
# 5         Yes             Yes  Month-to-month              Yes
# 6         Yes              No  Month-to-month              Yes
# 7          No              No  Month-to-month               No
# 8         Yes             Yes  Month-to-month              Yes
# 9          No              No        One year               No
#
#                PaymentMethod MonthlyCharges TotalCharges  Churn Count
# 0           Electronic check          29.85        29.85     No     1
# 1               Mailed check          56.95       1889.5     No     1
# 2               Mailed check          53.85       108.15    Yes     1
# 3  Bank transfer (automatic)          42.30      1840.75     No     1
# 4           Electronic check          70.70       151.65    Yes     1
# 5           Electronic check          99.65        820.5    Yes     1
# 6    Credit card (automatic)          89.10       1949.4     No     1
# 7               Mailed check          29.75        301.9     No     1
# 8           Electronic check         104.80      3046.05    Yes     1
# 9  Bank transfer (automatic)          56.15      3487.95     No     1
#
# [10 rows x 22 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
#  16  PaperlessBilling  7043 non-null   object
#  17  PaymentMethod     7043 non-null   object
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7043 non-null   object
#  20  Churn             7043 non-null   object
#  21  Count             7043 non-null   int64
# dtypes: float64(1), int64(3), object(18)
# memory usage: 1.2+ MB

# %%
df['TotalCharges'].dtypes
# Out:
# dtype('O')

# %%
df['gender'].value_counts()
# Out:
# Male      3555
# Female    3488
# Name: gender, dtype: int64

# %%
df['SeniorCitizen'].value_counts()
# Out:
# 0    5901
# 1    1142
# Name: SeniorCitizen, dtype: int64

# %%
#To replace seniorcitizen value with a Yes and No
df['SeniorCitizen'].replace(1,'Yes', inplace=True)
df['SeniorCitizen'].replace(0,'No', inplace=True)
df['SeniorCitizen'].value_counts()
# Out:
# No     5901
# Yes    1142
# Name: SeniorCitizen, dtype: int64

# %%
df1 = df[['gender', 'SeniorCitizen', 'Count']]
df1.groupby(['gender', 'SeniorCitizen']).count().reset_index()
# Out:
#    gender SeniorCitizen  Count
# 0  Female            No   2920
# 1  Female           Yes    568
# 2    Male            No   2981
# 3    Male           Yes    574

# %%
import matplotlib.pyplot as plt
df_demo=df.groupby(["gender", "SeniorCitizen"])["Count"].count().reset_index()
plt.figure(figsize=(10,5))
sns.barplot(x="gender", y= "Count", hue="SeniorCitizen", data=df_demo)
plt.title("Most Popular Demographics")
plt.xlabel("Gender")
plt.ylabel("No of subscribers")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-ffd218913325> in <module>
#       2 df_demo=df.groupby(["gender", "SeniorCitizen"])["Count"].count().reset_index()
#       3 plt.figure(figsize=(10,5))
# ----> 4 sns.barplot(x="gender", y= "Count", hue="SeniorCitizen", data=df_demo)
#       5 plt.title("Most Popular Demographics")
#       6 plt.xlabel("Gender")
#
# NameError: name 'sns' is not defined

# %%
#From the analysis, it is clear that popularity of the telco brand is more among male and female subscribers not senior citizens.And non-senior male citizens are likely to be telco customers than non-senior female citizens. 
#The marketing team should target their advertisements to senior citizens inorder to increase retention of customers.

# %%
churn_df = df[['PhoneService', 'InternetService',
       'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
       'StreamingTV', 'StreamingMovies', 'MonthlyCharges', 'Contract', 'Churn']][df['Churn'] == "Yes"]

churn_df.head()
# Out:
#    PhoneService InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# 2           Yes             DSL            Yes          Yes               No
# 4           Yes     Fiber optic             No           No               No
# 5           Yes     Fiber optic             No           No              Yes
# 8           Yes     Fiber optic             No           No              Yes
# 13          Yes     Fiber optic             No          Yes              Yes
#
#    TechSupport StreamingTV StreamingMovies  MonthlyCharges        Contract  \
# 2           No          No              No           53.85  Month-to-month
# 4           No          No              No           70.70  Month-to-month
# 5           No         Yes             Yes           99.65  Month-to-month
# 8          Yes         Yes             Yes          104.80  Month-to-month
# 13          No         Yes             Yes          103.70  Month-to-month
#
#    Churn
# 2    Yes
# 4    Yes
# 5    Yes
# 8    Yes
# 13   Yes

# %%
#Which 3 services are contributing to a higher monthly charge and resulting to customers churning? 
#(Use visualizations in explaining your analysis)
df['MonthlyCharges'].max()
# Out:
# 118.75

# %%
df_maxprice = df[['PhoneService','InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
            'TechSupport','StreamingTV', 'StreamingMovies', 'MonthlyCharges', 'Churn']][df['MonthlyCharges'] == 118.75]
df_maxprice
# Out:
#      PhoneService InternetService OnlineSecurity OnlineBackup  \
# 4586          Yes     Fiber optic            Yes          Yes
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies  MonthlyCharges  \
# 4586              Yes         Yes         Yes             Yes          118.75
#
#      Churn
# 4586    No

# %%
for col in ['PhoneService', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
            'TechSupport','StreamingTV', 'StreamingMovies']:
        plt.figure(figsize=(8,5))
        sns.barplot(x=col, y='MonthlyCharges', hue='Churn', data=df, palette="tab10")
        plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-9a5f39b25466> in <module>
#       2             'TechSupport','StreamingTV', 'StreamingMovies']:
#       3         plt.figure(figsize=(8,5))
# ----> 4         sns.barplot(x=col, y='MonthlyCharges', hue='Churn', data=df, palette="tab10")
#       5         plt.show()
#
# NameError: name 'sns' is not defined

# %%
#If the telco was to offer Phone as a standalone service, which type of contract would encourage customer retention?
df['Contract'].value_counts()
# Out:
# Month-to-month    3875
# Two year          1695
# One year          1473
# Name: Contract, dtype: int64

# %%
df_phone=df.groupby(["PhoneService", "Contract"])["Count"].count().reset_index()
plt.figure(figsize=(10,5))
sns.countplot(x="PhoneService", hue="Contract", data=df)
plt.xlabel("PhoneService")
plt.ylabel("No of subscribers")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-7f9aade0380e> in <module>
#       1 df_phone=df.groupby(["PhoneService", "Contract"])["Count"].count().reset_index()
#       2 plt.figure(figsize=(10,5))
# ----> 3 sns.countplot(x="PhoneService", hue="Contract", data=df)
#       4 plt.xlabel("PhoneService")
#       5 plt.ylabel("No of subscribers")
#
# NameError: name 'sns' is not defined

# %%
Text(0, 0.5, 'No of subsubsribers')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-516d4e268ec9> in <module>
# ----> 1 Text(0, 0.5, 'No of subsubsribers')
#
# NameError: name 'Text' is not defined

# %%
df3 = df[['MonthlyCharges','Churn','Count']]
df3.groupby(['MonthlyCharges','Churn']).count().reset_index()
# Out:
#       MonthlyCharges Churn  Count
# 0              18.25    No      1
# 1              18.40    No      1
# 2              18.55    No      1
# 3              18.70    No      2
# 4              18.75    No      1
# ...              ...   ...    ...
# 2365          118.20    No      1
# 2366          118.35   Yes      1
# 2367          118.60    No      2
# 2368          118.65    No      1
# 2369          118.75    No      1
#
# [2370 rows x 3 columns]

# %%
#If the company was to streamline all its services into 3 bouquet packages, what monthly prices will be appropriate for the following packages to keep customers from churning: 
#i. Basic, ii. Plus, iii. Premium
df['MonthlyCharges'].describe()
# Out:
# count    7043.000000
# mean       64.761692
# std        30.090047
# min        18.250000
# 25%        35.500000
# 50%        70.350000
# 75%        89.850000
# max       118.750000
# Name: MonthlyCharges, dtype: float64

# %%
plt.figure(figsize=(8,5))
sns.histplot(x="MonthlyCharges", hue ="Churn", data=df, kde=True,)
plt.xlabel("MonthlyCharges")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-e49635eaa275> in <module>
#       1 plt.figure(figsize=(8,5))
# ----> 2 sns.histplot(x="MonthlyCharges", hue ="Churn", data=df, kde=True,)
#       3 plt.xlabel("MonthlyCharges")
#
# NameError: name 'sns' is not defined

# %%
#Should the company strictly go paperless for their monthly billings as a technique of keeping their customers and why?
df['PaperlessBilling'].value_counts()
# Out:
# Yes    4171
# No     2872
# Name: PaperlessBilling, dtype: int64

# %%
plt.figure(figsize=(10,5))
sns.countplot(x="PaperlessBilling", hue="Churn", data=df)
plt.xlabel("PaperlessBilling")
plt.ylabel("No of subscribers")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-002e3e57a7a7> in <module>
#       1 plt.figure(figsize=(10,5))
# ----> 2 sns.countplot(x="PaperlessBilling", hue="Churn", data=df)
#       3 plt.xlabel("PaperlessBilling")
#       4 plt.ylabel("No of subscribers")
#
# NameError: name 'sns' is not defined

# %%
#No,going strictly paperless would make costumers using paperless billing to more likey churn.
